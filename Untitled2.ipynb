# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('coin_dataset.csv')

# Encode categorical columns
label_encoder = LabelEncoder()
data['first_face'] = label_encoder.fit_transform(data['first_face'])
data['throwing_style'] = label_encoder.fit_transform(data['throwing_style'])
data['Result'] = label_encoder.fit_transform(data['Result'])

# Separate data into X (input) and y (output)
X = data[['first_face', 'throwing_style']]
y = data['Result']

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0 )

# Create a neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_dim=2),  # Input layer
    tf.keras.layers.Dense(1, activation='sigmoid')  # Output layer (sigmoid activation for binary classification)
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

# Visualize training and validation losses and accuracies
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Losses')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracies')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Print the accuracies at the last training epoch
last_train_accuracy = history.history['accuracy'][-1]
last_val_accuracy = history.history['val_accuracy'][-1]
print(f'Last training accuracy at the last epoch: {last_train_accuracy:.4f}')
print(f'Validation accuracy at the last epoch: {last_val_accuracy:.4f}')

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/50
# 3/3 [==============================] - 1s 104ms/step - loss: 0.7017 - accuracy: 0.4750 - val_loss: 0.6773 - val_accuracy: 0.5500
# Epoch 2/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7010 - accuracy: 0.4750 - val_loss: 0.6776 - val_accuracy: 0.5500
# Epoch 3/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.7005 - accuracy: 0.4750 - val_loss: 0.6778 - val_accuracy: 0.5500
# Epoch 4/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7000 - accuracy: 0.4750 - val_loss: 0.6779 - val_accuracy: 0.5500
# Epoch 5/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6996 - accuracy: 0.4750 - val_loss: 0.6781 - val_accuracy: 0.5500
# Epoch 6/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6994 - accuracy: 0.4750 - val_loss: 0.6782 - val_accuracy: 0.5500
# Epoch 7/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6991 - accuracy: 0.4750 - val_loss: 0.6785 - val_accuracy: 0.5500
# Epoch 8/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6987 - accuracy: 0.4750 - val_loss: 0.6788 - val_accuracy: 0.5500
# Epoch 9/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6984 - accuracy: 0.4750 - val_loss: 0.6791 - val_accuracy: 0.5500
# Epoch 10/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6981 - accuracy: 0.4750 - val_loss: 0.6794 - val_accuracy: 0.5500
# Epoch 11/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6979 - accuracy: 0.4750 - val_loss: 0.6797 - val_accuracy: 0.5500
# Epoch 12/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6975 - accuracy: 0.4750 - val_loss: 0.6800 - val_accuracy: 0.5500
# Epoch 13/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6972 - accuracy: 0.4750 - val_loss: 0.6802 - val_accuracy: 0.5500
# Epoch 14/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6969 - accuracy: 0.4750 - val_loss: 0.6806 - val_accuracy: 0.5500
# Epoch 15/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6965 - accuracy: 0.4750 - val_loss: 0.6808 - val_accuracy: 0.4500
# Epoch 16/50
# 3/3 [==============================] - 0s 49ms/step - loss: 0.6962 - accuracy: 0.5500 - val_loss: 0.6810 - val_accuracy: 0.4500
# Epoch 17/50
# 3/3 [==============================] - 0s 51ms/step - loss: 0.6959 - accuracy: 0.5500 - val_loss: 0.6813 - val_accuracy: 0.4500
# Epoch 18/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.6955 - accuracy: 0.5500 - val_loss: 0.6816 - val_accuracy: 0.4500
# Epoch 19/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6953 - accuracy: 0.5500 - val_loss: 0.6818 - val_accuracy: 0.4500
# Epoch 20/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6949 - accuracy: 0.5500 - val_loss: 0.6822 - val_accuracy: 0.4500
# Epoch 21/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6946 - accuracy: 0.5500 - val_loss: 0.6826 - val_accuracy: 0.4500
# Epoch 22/50
# 3/3 [==============================] - 0s 31ms/step - loss: 0.6943 - accuracy: 0.5500 - val_loss: 0.6830 - val_accuracy: 0.4500
# Epoch 23/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6940 - accuracy: 0.5500 - val_loss: 0.6833 - val_accuracy: 0.4500
# Epoch 24/50
# 3/3 [==============================] - 0s 40ms/step - loss: 0.6936 - accuracy: 0.5500 - val_loss: 0.6835 - val_accuracy: 0.4500
# Epoch 25/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6933 - accuracy: 0.5500 - val_loss: 0.6839 - val_accuracy: 0.4500
# Epoch 26/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6931 - accuracy: 0.5875 - val_loss: 0.6841 - val_accuracy: 0.5000
# Epoch 27/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6928 - accuracy: 0.5375 - val_loss: 0.6843 - val_accuracy: 0.5000
# Epoch 28/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6924 - accuracy: 0.5375 - val_loss: 0.6846 - val_accuracy: 0.5000
# Epoch 29/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6922 - accuracy: 0.5375 - val_loss: 0.6849 - val_accuracy: 0.5000
# Epoch 30/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6919 - accuracy: 0.5375 - val_loss: 0.6853 - val_accuracy: 0.5000
# Epoch 31/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6917 - accuracy: 0.5375 - val_loss: 0.6856 - val_accuracy: 0.5000
# Epoch 32/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6915 - accuracy: 0.5375 - val_loss: 0.6859 - val_accuracy: 0.5000
# Epoch 33/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6911 - accuracy: 0.5375 - val_loss: 0.6861 - val_accuracy: 0.5000
# Epoch 34/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6910 - accuracy: 0.5375 - val_loss: 0.6865 - val_accuracy: 0.5000
# Epoch 35/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6907 - accuracy: 0.5375 - val_loss: 0.6868 - val_accuracy: 0.5000
# Epoch 36/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6905 - accuracy: 0.5375 - val_loss: 0.6871 - val_accuracy: 0.5000
# Epoch 37/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6902 - accuracy: 0.5375 - val_loss: 0.6873 - val_accuracy: 0.5000
# Epoch 38/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6900 - accuracy: 0.5375 - val_loss: 0.6877 - val_accuracy: 0.5000
# Epoch 39/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6898 - accuracy: 0.5375 - val_loss: 0.6881 - val_accuracy: 0.5000
# Epoch 40/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6895 - accuracy: 0.5375 - val_loss: 0.6885 - val_accuracy: 0.5000
# Epoch 41/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6893 - accuracy: 0.5375 - val_loss: 0.6888 - val_accuracy: 0.5000
# Epoch 42/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6890 - accuracy: 0.5375 - val_loss: 0.6891 - val_accuracy: 0.5000
# Epoch 43/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6888 - accuracy: 0.5375 - val_loss: 0.6895 - val_accuracy: 0.5000
# Epoch 44/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6886 - accuracy: 0.5375 - val_loss: 0.6897 - val_accuracy: 0.5000
# Epoch 45/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6883 - accuracy: 0.5375 - val_loss: 0.6899 - val_accuracy: 0.5000
# Epoch 46/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6882 - accuracy: 0.5375 - val_loss: 0.6902 - val_accuracy: 0.5000
# Epoch 47/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6880 - accuracy: 0.5375 - val_loss: 0.6904 - val_accuracy: 0.5000
# Epoch 48/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6878 - accuracy: 0.5375 - val_loss: 0.6907 - val_accuracy: 0.5000
# Epoch 49/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6877 - accuracy: 0.5375 - val_loss: 0.6909 - val_accuracy: 0.5000
# Epoch 50/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6875 - accuracy: 0.5375 - val_loss: 0.6912 - val_accuracy: 0.5000
# Last training accuracy at the last epoch: 0.5375
# Validation accuracy at the last epoch: 0.5000

# %%
from tensorflow.keras.utils import plot_model

# Modeli görselleştir
plot_model(model, show_shapes=True, rankdir="LR", to_file='model_plot.png')

# %%
# Load the dataset
data_test = pd.read_csv('coin_dataset_test.csv')

# Encode categorical columns
label_encoder = LabelEncoder()
data_test['first_face'] = label_encoder.fit_transform(data_test['first_face'])
data_test['throwing_style'] = label_encoder.fit_transform(data_test['throwing_style'])
data_test['Result'] = label_encoder.fit_transform(data_test['Result'])

# Separate data into X (input) and y (output)
X_test_custom = data_test[['first_face', 'throwing_style']]
y_test_custom = data_test['Result']

# Make predictions using the model
predictions = model.predict(X_test_custom)
rounded_predictions = np.round(predictions)  # Round the predictions (for binary classification)

# Print predictions to the screen
true_val = 0
for i in range(len(y_test_custom)):
    true_label = y_test_custom.iloc[i]
    predicted_label = rounded_predictions[i][0]

    if true_label == predicted_label:
        print(f"Data #{i + 1}: Correct Prediction ({true_label})")
        true_val += 1
    else:
        print(f"Data #{i + 1}: Incorrect Prediction - True: {true_label}, Predicted: {predicted_label}")

print(f"Percentage of correct predictions: {(true_val / (i + 1) * 100)}")
# Out:
# 1/1 [==============================] - 0s 33ms/step
# Data #1: Correct Prediction (0)
# Data #2: Correct Prediction (0)
# Data #3: Correct Prediction (0)
# Data #4: Correct Prediction (0)
# Data #5: Correct Prediction (0)
# Data #6: Incorrect Prediction - True: 1, Predicted: 0.0
# Data #7: Incorrect Prediction - True: 1, Predicted: 0.0
# Data #8: Incorrect Prediction - True: 1, Predicted: 0.0
# Data #9: Correct Prediction (0)
# Data #10: Correct Prediction (0)
# Data #11: Correct Prediction (0)
# Data #12: Correct Prediction (0)
# Percentage of correct predictions: 75.0
